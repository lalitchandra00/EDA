# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Travel.csv")

# %%
df_cpy = df.copy()

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
df.describe()
# Out:
#           CustomerID    ProdTaken          Age     CityTier  DurationOfPitch  \
# count    4888.000000  4888.000000  4662.000000  4888.000000      4637.000000
# mean   202443.500000     0.188216    37.622265     1.654255        15.490835
# std      1411.188388     0.390925     9.316387     0.916583         8.519643
# min    200000.000000     0.000000    18.000000     1.000000         5.000000
# 25%    201221.750000     0.000000    31.000000     1.000000         9.000000
# 50%    202443.500000     0.000000    36.000000     1.000000        13.000000
# 75%    203665.250000     0.000000    44.000000     3.000000        20.000000
# max    204887.000000     1.000000    61.000000     3.000000       127.000000
#
#        NumberOfPersonVisiting  NumberOfFollowups  PreferredPropertyStar  \
# count             4888.000000        4843.000000            4862.000000
# mean                 2.905074           3.708445               3.581037
# ...

# %%
df.shape
# Out:
# (4888, 20)

# %%
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head(2)
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
#
#   Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0   Salaried  Female                       3                3.0
# 1   Salaried    Male                       3                4.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0         Deluxe                    3.0        Single            1.0
# 1         Deluxe                    4.0      Divorced            2.0
#
#    Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 0         1                       2       1                       0.0
# 1         0                       3       1                       2.0
#
#   Designation  MonthlyIncome
# 0     Manager        20993.0
# 1     Manager        20130.0

# %% [markdown]
# # Data Cleaning
# ### Going column by column and
# 1. checking values (for completely different data or spelling mistakes or outliers)
# 2. checking datatypes
# 3. filling nulls

# %% [markdown]
# ## ProdTaken

# %%
df['ProdTaken'].value_counts()
# Out:
# ProdTaken
# 0    3968
# 1     920
# Name: count, dtype: int64

# %% [markdown]
# ## Age

# %%
df['Age'].value_counts(sort = True)
# Out:
# Age
# 35.0    237
# 36.0    231
# 34.0    211
# 31.0    203
# 30.0    199
# 32.0    197
# 33.0    189
# 37.0    185
# 29.0    178
# 38.0    176
# 41.0    155
# 39.0    150
# 28.0    147
# 40.0    146
# 42.0    142
# 27.0    138
# 43.0    130
# 46.0    121
# 45.0    116
# 26.0    106
# 44.0    105
# 51.0     90
# 47.0     88
# 50.0     86
# 25.0     74
# 52.0     68
# 53.0     66
# 49.0     65
# 48.0     65
# 55.0     64
# 54.0     61
# 56.0     58
# 24.0     56
# 23.0     46
# 22.0     46
# 59.0     44
# 21.0     41
# 20.0     38
# 19.0     32
# 58.0     31
# 57.0     29
# 60.0     29
# 18.0     14
# 61.0      9
# Name: count, dtype: int64

# %%
df['Age'].mean()
# Out:
# np.float64(37.62226512226512)

# %%
df['Age'].fillna(38, axis = 0, inplace = True)
# Out:
# C:\Users\Lalit Chandra\AppData\Local\Temp\ipykernel_1180\872647647.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(38, axis = 0, inplace = True)

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Age'].value_counts(sort = True)
# Out:
# Age
# 38.0    402
# 35.0    237
# 36.0    231
# 34.0    211
# 31.0    203
# 30.0    199
# 32.0    197
# 33.0    189
# 37.0    185
# 29.0    178
# 41.0    155
# 39.0    150
# 28.0    147
# 40.0    146
# 42.0    142
# 27.0    138
# 43.0    130
# 46.0    121
# 45.0    116
# 26.0    106
# 44.0    105
# 51.0     90
# 47.0     88
# 50.0     86
# 25.0     74
# 52.0     68
# 53.0     66
# 49.0     65
# 48.0     65
# 55.0     64
# 54.0     61
# 56.0     58
# 24.0     56
# 23.0     46
# 22.0     46
# 59.0     44
# 21.0     41
# 20.0     38
# 19.0     32
# 58.0     31
# 57.0     29
# 60.0     29
# 18.0     14
# 61.0      9
# Name: count, dtype: int64

# %% [markdown]
# ## TypeofContact

# %%
df['TypeofContact'].value_counts()
# Out:
# TypeofContact
# Self Enquiry       3444
# Company Invited    1419
# Name: count, dtype: int64

# %%
df['TypeofContact'].isnull().sum()
# Out:
# np.int64(25)

# %%
df['TypeofContact'] = df['TypeofContact'].map({'Self Enquiry' : 1, 'Company Invited' : 2})

# %%
df['TypeofContact']
# Out:
# 0       1.0
# 1       2.0
# 2       1.0
# 3       2.0
# 4       1.0
#        ...
# 4883    1.0
# 4884    2.0
# 4885    1.0
# 4886    1.0
# 4887    1.0
# Name: TypeofContact, Length: 4888, dtype: float64

# %%
df['TypeofContact'].mode()
# Out:
# 0    1.0
# Name: TypeofContact, dtype: float64

# %%
df['TypeofContact'] = df['TypeofContact'].fillna(df['TypeofContact'].mode()[0])

# %%
df['TypeofContact'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## CityTier

# %%
df['CityTier'].value_counts()
# Out:
# CityTier
# 1    3190
# 3    1500
# 2     198
# Name: count, dtype: int64

# %%
df['CityTier'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['DurationOfPitch'].value_counts()
# Out:
# DurationOfPitch
# 9.0      483
# 7.0      342
# 8.0      333
# 6.0      307
# 16.0     274
# 15.0     269
# 14.0     253
# 10.0     244
# 13.0     223
# 11.0     205
# 12.0     195
# 17.0     172
# 30.0      95
# 22.0      89
# 31.0      83
# 23.0      79
# 18.0      75
# 32.0      74
# 29.0      74
# 25.0      73
# 21.0      73
# 27.0      72
# 26.0      72
# 24.0      70
# 35.0      66
# 20.0      65
# 28.0      61
# 33.0      57
# 19.0      57
# 34.0      50
# 36.0      44
# 5.0        6
# 126.0      1
# 127.0      1
# Name: count, dtype: int64

# %%
df['DurationOfPitch'].isnull().sum()
# Out:
# np.int64(251)

# %%
df['DurationOfPitch'] = df['DurationOfPitch'].fillna(df['DurationOfPitch'].mean())

# %%
df['DurationOfPitch'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Occupation

# %%
df['Occupation'].value_counts()
# Out:
# Occupation
# Salaried          2368
# Small Business    2084
# Large Business     434
# Free Lancer          2
# Name: count, dtype: int64

# %%
df['Occupation'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Occupation'] = df['Occupation'].map({'Salaried' : 1, 'Small Business' : 2, 'Large Business' : 3, 'Free Lancer' : 4})

# %% [markdown]
# ## Gender

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male       2916
# Female     1817
# Fe Male     155
# Name: count, dtype: int64

# %%
df['Gender'].replace('Fe Male', 'Female',inplace = True)
# Out:
# C:\Users\Lalit Chandra\AppData\Local\Temp\ipykernel_1180\2737011099.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].replace('Fe Male', 'Female',inplace = True)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      2916
# Female    1972
# Name: count, dtype: int64

# %%
df['Gender'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Gender'] = df['Gender'].map({'Male' : 1, 'Female' : 2})

# %% [markdown]
# ## NumberOfPersonVisiting

# %%
df['NumberOfPersonVisiting'].value_counts()
# Out:
# NumberOfPersonVisiting
# 3    2402
# 2    1418
# 4    1026
# 1      39
# 5       3
# Name: count, dtype: int64

# %%
df['NumberOfPersonVisiting'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProdTaken', 'Age', 'TypeofContact', 'CityTier',
#        'DurationOfPitch', 'Occupation', 'Gender', 'NumberOfPersonVisiting',
#        'NumberOfFollowups', 'ProductPitched', 'PreferredPropertyStar',
#        'MaritalStatus', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore',
#        'OwnCar', 'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome'],
#       dtype='object')

# %% [markdown]
# ## NumberOfFollowups

# %%
df['NumberOfFollowups'].value_counts()
# Out:
# NumberOfFollowups
# 4.0    2068
# 3.0    1466
# 5.0     768
# 2.0     229
# 1.0     176
# 6.0     136
# Name: count, dtype: int64

# %%
df['NumberOfFollowups'].isnull().sum()
# Out:
# np.int64(45)

# %%
df['NumberOfFollowups'] = df['NumberOfFollowups'].fillna(df['NumberOfFollowups'].mean())

# %%
df['NumberOfFollowups'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## ProductPitched

# %%
df['ProductPitched'].value_counts()
# Out:
# ProductPitched
# Basic           1842
# Deluxe          1732
# Standard         742
# Super Deluxe     342
# King             230
# Name: count, dtype: int64

# %%
df['ProductPitched'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['ProductPitched'] = df['ProductPitched'].map({'Basic' : 1, 'Deluxe' : 2, 'Standard' : 3, 'Super Deluxe' : 4, 'King' : 5})

# %%
df['ProductPitched'].value_counts()
# Out:
# ProductPitched
# 1    1842
# 2    1732
# 3     742
# 4     342
# 5     230
# Name: count, dtype: int64

# %% [markdown]
# ## PreferredPropertyStar

# %%
df['PreferredPropertyStar'].value_counts()
# Out:
# PreferredPropertyStar
# 3.0    2993
# 5.0     956
# 4.0     913
# Name: count, dtype: int64

# %%
df['PreferredPropertyStar'].isnull().sum()
# Out:
# np.int64(26)

# %%
df['PreferredPropertyStar'] = df['PreferredPropertyStar'].fillna(df['PreferredPropertyStar'].mode()[0])

# %%
df['PreferredPropertyStar'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## MaritalStatus

# %%
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married      2340
# Divorced      950
# Single        916
# Unmarried     682
# Name: count, dtype: int64

# %%
df['MaritalStatus'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['MaritalStatus'] = df['MaritalStatus'].replace('Single', 'Unmarried')

# %%
df['MaritalStatus'] = df['MaritalStatus'].map({'Married' : 1, 'Divorced' : 2, 'Unmarried' : 3})

# %% [markdown]
# ## NumberOfTrips

# %%
df['NumberOfTrips'].value_counts()
# Out:
# NumberOfTrips
# 2.0     1464
# 3.0     1079
# 1.0      620
# 4.0      478
# 5.0      458
# 6.0      322
# 7.0      218
# 8.0      105
# 19.0       1
# 21.0       1
# 20.0       1
# 22.0       1
# Name: count, dtype: int64

# %%
df['NumberOfTrips'].isnull().sum()
# Out:
# np.int64(140)

# %%
df['NumberOfTrips'] = df['NumberOfTrips'].fillna(df['NumberOfTrips'].mode()[0])

# %%
df['NumberOfTrips'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Passport

# %%
df['Passport'].value_counts()
# Out:
# Passport
# 0    3466
# 1    1422
# Name: count, dtype: int64

# %%
df['Passport'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## PitchSatisfactionScore

# %%
df['PitchSatisfactionScore'].value_counts()
# Out:
# PitchSatisfactionScore
# 3    1478
# 5     970
# 1     942
# 4     912
# 2     586
# Name: count, dtype: int64

# %%
df['PitchSatisfactionScore'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## OwnCar

# %%
df['OwnCar'].value_counts()
# Out:
# OwnCar
# 1    3032
# 0    1856
# Name: count, dtype: int64

# %%
df['OwnCar'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## NumberOfChildrenVisiting

# %%
df['NumberOfChildrenVisiting'].value_counts()
# Out:
# NumberOfChildrenVisiting
# 1.0    2080
# 2.0    1335
# 0.0    1082
# 3.0     325
# Name: count, dtype: int64

# %%
df['NumberOfChildrenVisiting'].isnull().sum()
# Out:
# np.int64(66)

# %%
df['NumberOfChildrenVisiting'] = df['NumberOfChildrenVisiting'].fillna(df['NumberOfChildrenVisiting'].mode()[0])

# %%
df['NumberOfChildrenVisiting'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Designation

# %%
df['Designation'].value_counts()
# Out:
# Designation
# Executive         1842
# Manager           1732
# Senior Manager     742
# AVP                342
# VP                 230
# Name: count, dtype: int64

# %%
df['Designation'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Designation'] = df['Designation'].map({'Executive' : 1, 'Manager' : 2, 'Senior Manager' : 3, 'AVP' : 4, 'VP' : 5})

# %% [markdown]
# ## MonthlyIncome

# %%
df['MonthlyIncome'].isnull().sum()
# Out:
# np.int64(233)

# %%
df['MonthlyIncome'].unique()
# Out:
# array([20993., 20130., 17090., ..., 22097., 22995., 21471.], shape=(2476,))

# %%
df['MonthlyIncome'] = df['MonthlyIncome'].fillna(round(df['MonthlyIncome'].mean(),ndigits = 2))

# %%
df['MonthlyIncome'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age  TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0            1.0         3              6.0
# 1      200001          0  49.0            2.0         1             14.0
# 2      200002          1  37.0            1.0         1              8.0
# 3      200003          0  33.0            2.0         1              9.0
# 4      200004          0  38.0            1.0         1              8.0
#
#    Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0           1       2                       3                3.0
# 1           1       1                       3                4.0
# 2           4       1                       3                4.0
# 3           1       2                       2                3.0
# 4           2       1                       2                3.0
#
#    ProductPitched  PreferredPropertyStar  MaritalStatus  NumberOfTrips  \
# ...

# %%
df.drop(columns = ['CustomerID'], axis = 0, inplace = True)

# %%
df.head()
# Out:
#    ProdTaken   Age  TypeofContact  CityTier  DurationOfPitch  Occupation  \
# 0          1  41.0            1.0         3              6.0           1
# 1          0  49.0            2.0         1             14.0           1
# 2          1  37.0            1.0         1              8.0           4
# 3          0  33.0            2.0         1              9.0           1
# 4          0  38.0            1.0         1              8.0           2
#
#    Gender  NumberOfPersonVisiting  NumberOfFollowups  ProductPitched  \
# 0       2                       3                3.0               2
# 1       1                       3                4.0               2
# 2       1                       3                4.0               1
# 3       2                       2                3.0               1
# 4       1                       2                3.0               1
#
#    PreferredPropertyStar  MaritalStatus  NumberOfTrips  Passport  \
# ...
